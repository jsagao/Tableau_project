# %% [markdown]
# # DTSC 600 — Analysis Notebook
#
# Use this notebook for quick EDA and to prepare data for Tableau.
#
# Tips:
# - Put raw files in `data/raw/`.
# - Run `src/preprocess.py` to create `data/processed/clean_dataset.csv`.
# - In Tableau, use **Replace Data Source** to that processed CSV.

# %%
import pandas as pd
from pathlib import Path
processed = Path('../data/processed/clean_dataset.csv')
if processed.exists():
    df = pd.read_csv(processed)
    display(df.head())
else:
    print('Run `python ../src/preprocess.py` after adding CSVs to ../data/raw/')
